# %% [markdown]
# # Projeto Tratamento de dados Base de dados Netflix
#
# https://www.youtube.com/watch?v=b7Kd0fLwgO4&t=1325s
#
# In this video, you will learn how to work on a real project of Data Analysis with Python. Questions are given in the project and then solved with the help of Python. It is a project of Data Analysis with Python or you can say, Data Science with Python.
#
# The commands that we used in this project :
#
#     head() - It shows the first N rows in the data (by default, N=5).
#     tail () - It shows the last N rows in the data (by default, N=5).
#     shape - It shows the total no. of rows and no. of columns of the dataframe.
#     size - To show No. of total values(elements) in the dataset.
#     columns - To show each Column Name.
#     dtypes - To show the data-type of each column.
#     info() - To show indexes, columns, data-types of each column, memory at once.
#     value_counts - In a column, it shows all the unique values with their count. It can be applied on a single column only.
#     unique() - It shows the all unique values of the series.
#     nunique() - It shows the total no. of unique values in the series.
#     duplicated( ) - To check row wise and detect the Duplicate rows.
#     isnull( ) - To show where Null value is present.
#     dropna( ) - It drops the rows that contains all missing values.
#     isin( ) - To show all records including particular elements.
#     str.contains( ) - To get all records that contains a given string.
#     str.split( ) - It splits a column's string into different columns.
#     to_datetime( ) - Converts the data-type of Date-Time Column into datetime[ns] datatype.
#     dt.year.value_counts( ) - It counts the occurrence of all individual years in Time column.
#     groupby( ) - Groupby is used to split the data into groups based on some criteria.
#     sns.countplot(df['Col_name']) - To show the count of all unique values of any column in the form of bar graph.
#     max( ), min( ) - It shows the maximum/minimum value of the series.
#     mean( ) - It shows the mean value of the series.
#
#
# You will learn these things also:
# Creating New Columns & Dataframe
# Filtering (Single Column & Multiple Columns)
# Filtering with And and OR
# Seaborn Library - Bar Graphs
#
# ..............................................
#
# Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.
# Task. 2) Is there any Null Value present in any column ? Show with Heat-map.
# Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?
# Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.
# Q. 4) Show all the Movies that were released in year 2000.
# Q. 5) Show only the Titles of all TV Shows that were released in India only.
# Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?
# Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".
# Q. 8) In how many movies/shows, Tom Cruise was cast ?
# Q. 9) What are the different Ratings defined by Netflix ?
# Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?
# Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?
# Q. 10) What is the maximum duration of a Movie/Show on Netflix ?
# Q. 11) Which individual country has the Highest No. of TV Shows ?
# Q. 12) How can we sort the dataset by Year ?
# Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
#carrega bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Montar drive no Google
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Base de dados em .csv foi hospedada no Google Driver na pasta BASES_Analise

# %%
# Carregar o dataset
caminho = '/content/drive/MyDrive/BASES_Analise/'
df = data = pd.read_csv(caminho + '/Project_Netflix.csv')

# %% [markdown]
# # O df.head() exibirá as 5 primeiras linhas do DataFrame df.

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # O comando df.tail() exibirá as últimas 5 linhas do DataFrame df.

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# # O comando data.shape retorna as dimensões do DataFrame data na forma de uma tupla, onde :
#
#     O primeiro valor representa o número de linhas (observações).
#     O segundo valor representa o número de colunas (variáveis).

# %%
data.shape
# Out:
# (7789, 11)

# %% [markdown]
# # O comando df.size retorna o número total de elementos no DataFrame df. Esse valor é obtido multiplicando o número de linhas pelo número de colunas.

# %%
df.size
# Out:
# 85679

# %% [markdown]
# # O comando df.columns retorna uma lista com os nomes de todas as colunas do DataFrame df.

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # O comando df.dtypes exibe o tipo de dados de cada coluna no DataFrame df.

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# # O comando df.info() mostra um resumo conciso do DataFrame df, incluindo :
#
#     O número total de entradas (linhas).
#     O nome e tipo de cada coluna.
#     A contagem de valores não nulos em cada coluna.
#     O uso de memória do DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %% [markdown]
# # Exibe as linhas duplicadas no DataFrame

# %%
duplicatas = df[df.duplicated()]
print(duplicatas)
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# # O método drop_duplicates com o parâmetro (inplace=True) modifica o DataFrame original, mas não retorna um novo DataFrame.

# %%
# Remove as linhas duplicadas
df_sem_duplicatas = df.drop_duplicates(inplace=True)
print(df_sem_duplicatas)
# Out:
# None

# %%
df.shape
# Out:
# (7787, 11)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # O método df.isnull() retorna um novo DataFrame do mesmo tamanho que df, onde cada célula contém True se o valor correspondente é NaN (ou seja, um valor nulo) e False caso contrário. Isso é útil para identificar valores ausentes.
#
#     Para ver o número total de valores nulos em cada coluna, você pode usar :
#     df.isnull().sum()

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %% [markdown]
# # 🔴 Para ver o número total de valores nulos em cada coluna.

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# # O comando sns.heatmap(df.isnull()) utiliza a biblioteca Seaborn para criar um mapa de calor que visualiza a presença de valores nulos em um DataFrame. Cada célula do mapa de calor representa um valor do DataFrame, onde:
#
#     Cores diferentes indicam a presença (True ou False) de valores nulos.
#     Normalmente, o padrão é que a cor clara (ou branca) representa valores nulos, enquanto a cor escura representa valores não nulos.

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
'''# Ajustar o tamanho da figura
plt.figure(figsize=(10, 6))

# criando o heatmap com cores do time do Bahia
sns.heatmap(df.isnull(),
            cmap=sns.color_palette(["#0033A0", "#FF0000"]),  # Azul, Vermelho e branco (Bahia)
            cbar=True,      # Remove a barra de cor
            yticklabels=True)  # Oculta os rótulos do eixo Y se forem irrelevantes

# Adicionar título e rótulos nos eixos
plt.title('Mapa de Valores Nulos - BBMP', fontsize=16)
plt.xlabel('Colunas', fontsize=12)
plt.ylabel('Linhas', fontsize=12)

# Mostrar o gráfico
plt.show()
'''
# Out:
# '# Ajustar o tamanho da figura\nplt.figure(figsize=(10, 6))\n\n# criando o heatmap com cores do time do Bahia\nsns.heatmap(df.isnull(),\n            cmap=sns.color_palette(["#0033A0", "#FF0000"]),  # Azul, Vermelho e branco (Bahia)\n            cbar=True,      # Remove a barra de cor\n            yticklabels=True)  # Oculta os rótulos do eixo Y se forem irrelevantes\n\n# Adicionar título e rótulos nos eixos\nplt.title(\'Mapa de Valores Nulos - BBMP\', fontsize=16)\nplt.xlabel(\'Colunas\', fontsize=12)\nplt.ylabel(\'Linhas\', fontsize=12)\n\n# Mostrar o gráfico\nplt.show()\n'

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # O comando df[df['Title'].isin(['House of Cards'])] é utilizado para filtrar um DataFrame (df) e retornar apenas as linhas em que a coluna 'Title' contém o valor 'House of Cards'.

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # O comando df['Title'] listará todas as informações dessa coluna.

# %%
df['Title']
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %% [markdown]
# # O método query() da biblioteca pandas serve para filtrar um DataFrame chamado df. Ela verifica quais linhas têm a coluna Title que corresponde a "Breaking Bad" ou "House of Cards".
#
# ???

# %%
df.query('Title in ["Breaking Bad", "House of Cards"]')
# Out:
#      Show_Id Category           Title  \
# 1089   s1090  TV Show    Breaking Bad
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 1089                                                NaN
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 1089  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...  United States
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration  \
# 1089    August 2, 2013  TV-MA  5 Seasons
# 2832  November 2, 2018  TV-MA  6 Seasons
#
#                                          Type  \
# 1089  Crime TV Shows, TV Dramas, TV Thrillers
# 2832                  TV Dramas, TV Thrillers
#
#                                             Description
# 1089  A high school chemistry teacher dying of cance...
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# filtered_df = df[df['Title'].str.contains('house of cards', case=False)]
# filtered_df = df[df['Title'].str.contains('House of Cards', na=False)]

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'], format="%B %d, %Y", errors='coerce')

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.set_facecolor('lightgray')
df['Date_N'].dt.year.value_counts().plot(kind='bar', color=['blue', 'red', 'white'])
# Out:
# <Axes: xlabel='Date_N'>

# %%
# Contar o número de ocorrências por ano
#contagem_por_ano = df['Date_N'].dt.year.value_counts()
#print(contagem_por_ano)

# %%
# df = df.rename(columns={'show_id':'Show_Id', 'type':'Category', 'title':'Title','director':'Director', 'cast':'Cast', 'country':'Country', 'date_added':'Date_Added', 'release_year':'Release_Date', 'rating':'Rating', 'duration':'Duration', 'listed_in':'Type', 'description':'Description'})

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# Criando o gráfico de contagem com as cores azul e vermelho
sns.countplot(x='Category', data=data, palette=['blue', 'red'])

# Exibindo o gráfico
plt.show()
# Out:
# <ipython-input-162-f4d5f620b5be>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', data=data, palette=['blue', 'red'])

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
df['Year' ] = df['Date_N'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2020) ]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
# Filtrando o DataFrame
filtered_data = df[(df['Category'] == 'Movie') & (df['Year'] == 2018)]

# Criando o gráfico de contagem com as cores azul e vermelho
sns.countplot(x='Category', data=filtered_data, palette=['blue', 'red'])

# Exibindo o gráfico
plt.show()
# Out:
# <ipython-input-167-c0237ab4ada6>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', data=filtered_data, palette=['blue', 'red'])
# <ipython-input-167-c0237ab4ada6>:5: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.countplot(x='Category', data=filtered_data, palette=['blue', 'red'])

# %%
df[(df['Category'] == 'Movie') & (data['Year'] == 2020) ]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df[ (df['Category' ] == 'TV Show') & (df['Country' ] == 'Brazil') ]
# Out:
#      Show_Id Category                              Title  \
# 0         s1  TV Show                                 3%
# 218     s219  TV Show                    A Queen Is Born
# 322     s323  TV Show                Afronta! Facing It!
# 531     s532  TV Show            Anitta: Made In Honório
# 989     s990  TV Show                         Blood Pact
# 1052   s1053  TV Show                             Borges
# 1115   s1116  TV Show                        Brotherhood
# 1626   s1627  TV Show              Dating Around: Brazil
# 1905   s1906  TV Show                     Earth to Luna!
# 2486   s2487  TV Show             Good Morning, Verônica
# 3416   s3417  TV Show                       Kissing Game
# 3814   s3815  TV Show                    Lugar de Mulher
# 4233   s4234  TV Show               Most Beautiful Thing
# 4369   s4370  TV Show                        Mystery Lab
# 4502   s4503  TV Show                   Nobody's Looking
# ...

# %%
df[ (df['Category' ] == 'TV Show') & (df['Country' ] == 'India') ] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df[(df['Category' ] == 'Movie') & (df['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
df['Duration'].hist(bins=20)
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criando a figura e o eixo
fig, ax = plt.subplots()

# Definindo o fundo do gráfico como cinza claro
ax.set_facecolor('lightgray')

# Criando o histograma dos dados
n, bins, patches = ax.hist(df['Duration'], bins=20)

# Definindo as cores das barras alternadamente entre azul, vermelho e branco
colors = ['blue', 'red', 'white']
for i, patch in enumerate(patches):
    patch.set_facecolor(colors[i % len(colors)])  # Alterna entre as cores

# Exibindo o gráfico
plt.show()

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
df[(df['Category'] == 'Movie')] ['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Johnnie To                 8
# Name: count, dtype: int64

# %%
df[(df['Category'] == 'TV Show')] ['Director'].value_counts().head(10)
# Out:
# Director
# Alastair Fothergill           3
# Shin Won-ho                   2
# Iginio Straffi                2
# Rob Seidenglanz               2
# Stan Lathan                   2
# Ken Burns                     2
# Serdar Akar                   1
# Cosima Spender                1
# Jani Lachauer, Jakob Schuh    1
# Jalil Lespert                 1
# Name: count, dtype: int64

# %%
df[ (df['Category' ] == 'Movie') & (df['Type' ] == 'Comedies') ]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
 df[(df['Category'] == 'Movie') & (df['Type'] == 'Comedies') | (df['Country'] == 'Brazil')]
# Out:
#      Show_Id Category                     Title                Director  \
# 0         s1  TV Show                        3%                     NaN
# 33       s34    Movie              #realityhigh        Fernando Lebrija
# 72       s73    Movie                  17 Again             Burr Steers
# 84       s85    Movie                 21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie      A Bad Moms Christmas  Jon Lucas, Scott Moore
# ...      ...      ...                       ...                     ...
# 7592   s7591    Movie  Whindersson Nunes: Adult         Diego Pignataro
# 7623   s7622    Movie                 Wild Oats            Andy Tennant
# 7634   s7633    Movie              Wine Country             Amy Poehler
# 7664   s7663    Movie                   Work It           Laura Terruso
# 7758   s7757  TV Show                        Z4                     NaN
#
#                                                    Cast  \
# ...

# %%
df[ (df['Category' ] == 'TV Show') & (df['Type'] == 'Comedies') | (df['Country'] == 'Brazil')]
# Out:
#      Show_Id Category                      Title  \
# 0         s1  TV Show                         3%
# 208     s209    Movie           A new Capitalism
# 218     s219  TV Show            A Queen Is Born
# 320     s321    Movie  Afonso Padilha: Classless
# 322     s323  TV Show        Afronta! Facing It!
# ...      ...      ...                        ...
# 6657   s6656  TV Show              The Mechanism
# 7046   s7045    Movie      Thiago Ventura: POKAS
# 7385   s7384  TV Show                 Vai Anitta
# 7592   s7591    Movie   Whindersson Nunes: Adult
# 7758   s7757  TV Show                         Z4
#
#                            Director  \
# 0                               NaN
# 208                             NaN
# 218                    Carla Barros
# 320    Junior Carelli, Rudge Campos
# 322                 Juliana Vicente
# ...                             ...
# 6657                            NaN
# 7046  Fabio Ock, Joana Mazzucchelli
# 7385                            NaN
# ...

# %%
df[df['Cast' ] == 'Selton Mello']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
df_new = df.dropna()

# %%
df_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
df_new[df_new['Cast' ].str.contains('Wagner Moura')]
# Out:
#      Show_Id Category         Title         Director  \
# 5499   s5499    Movie        Sergio      Greg Barker
# 7198   s7197    Movie         Trash   Stephen Daldry
# 7489   s7488    Movie  Wasp Network  Olivier Assayas
#
#                                                    Cast  \
# 5499  Wagner Moura, Ana de Armas, Brían F. O'Byrne, ...
# 7198  Wagner Moura, Martin Sheen, Rooney Mara, Selto...
# 7489  Penélope Cruz, Edgar Ramírez, Wagner Moura, Ga...
#
#                               Country     Release_Date Rating Duration  \
# 5499                    United States   April 17, 2020      R  119 min
# 7198  United Kingdom, Brazil, Germany  January 1, 2019      R  114 min
# 7489   France, Brazil, Spain, Belgium    June 19, 2020  TV-MA  128 min
#
#                                          Type  \
# 5499               Dramas, Independent Movies
# 7198    Dramas, Independent Movies, Thrillers
# 7489  Dramas, International Movies, Thrillers
#
# ...

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %% [markdown]
# # Mostrará todas as Categorias

# %%
df["Rating"]
# Out:
# 0       TV-MA
# 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
#         ...
# 7784    TV-MA
# 7785    TV-14
# 7786    TV-MA
# 7787    TV-PG
# 7788    TV-MA
# Name: Rating, Length: 7787, dtype: object

# %%
df["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df[df["Rating"]=="nan"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
df[['Country', 'Category', "Rating"]]
# Out:
#                                                 Country Category Rating
# 0                                                Brazil  TV Show  TV-MA
# 1                                                Mexico    Movie  TV-MA
# 2                                             Singapore    Movie      R
# 3                                         United States    Movie  PG-13
# 4                                         United States    Movie  PG-13
# ...                                                 ...      ...    ...
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    Movie  TV-MA
# 7785                                              India    Movie  TV-14
# 7786                                                NaN    Movie  TV-MA
# 7787                                          Australia  TV Show  TV-PG
# 7788              United Kingdom, Canada, United States    Movie  TV-MA
#
# [7787 rows x 3 columns]

# %%
df [(df ['Country' ] == 'India')&(df['Category' ] == 'TV Show' )&(df ['Rating' ] == 'TV-14' )]
# Out:
#      Show_Id Category                                    Title     Director  \
# 86       s87  TV Show             21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                                7 (Seven)  Nizar Shafi
# 340     s341  TV Show                             Agent Raghav          NaN
# 533     s534  TV Show                      Anjaan: Rural Myths          NaN
# 534     s535  TV Show              Anjaan: Special Crimes Unit          NaN
# 686     s687  TV Show              Bad Boy Billionaires: India          NaN
# 698     s699  TV Show               Badalte Rishton Ki Dastaan          NaN
# 881     s882  TV Show                           Bhaage Re Mann          NaN
# 2331   s2332  TV Show                Gabru: Hip Hop Revolution          NaN
# 3164   s3165  TV Show                           Jhansi Ki Rani          NaN
# 3354   s3355  TV Show                 Khan: No. 1 Crime Hunter          NaN
# ...

# %%
df [(df ['Country' ] == 'Brazil')&(df['Category' ] == 'Movie' )&(df ['Rating' ] == 'TV-MA' )].shape
# Out:
# (28, 13)

# %%
df [(df ['Country' ] == 'India')&(df['Category' ] == 'TV Show' )&(df ['Rating' ] == 'TV-14' )].shape
# Out:
# (23, 13)

# %%
df [(df ['Category' ] == 'Movie' )&(df ['Rating' ] == 'R')&(df['Year' ]>2019)]
# Out:
#      Show_Id Category                 Title                       Director  \
# 14       s15    Movie                  3022                     John Suits
# 104     s105    Movie    30 Minutes or Less                Ruben Fleischer
# 148     s149    Movie  A Bad Moms Christmas         Jon Lucas, Scott Moore
# 165     s166    Movie    A Clockwork Orange                Stanley Kubrick
# 175     s176    Movie         A Ghost Story                   David Lowery
# ...      ...      ...                   ...                            ...
# 7578   s7577    Movie     Wheels of Fortune           Shaun Paul Piccinino
# 7613   s7612    Movie        Whose Streets?    Sabaah Folayan, Damon Davis
# 7627   s7626    Movie              Wildling                     Fritz Böhm
# 7659   s7658    Movie             Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie         Yes, God, Yes                    Karen Maine
#
#                                                    Cast  \
# ...

# %%
df [(df ['Category' ] == 'Movie' )&(df ['Rating' ] == 'R')&(df['Year' ]>2019)].shape
# Out:
# (224, 13)

# %% [markdown]
# # Questão 10 - Qual a duração maxima de filmes e Shows na Netflix.

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df [ ['Minutes', 'Unit']] = df ['Duration'].str.split(' ', expand=True)

# %%
df.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df ['Minutes' ].dtype
# Out:
# dtype('O')

# %%
df ['Minutes' ] = df ['Minutes' ]. astype(int)

# %%
df ['Minutes' ].dtype
# Out:
# dtype('int64')

# %%
df ['Minutes' ].max()
# Out:
# 312

# %%
df [df ['Minutes' ] == 312]
# Out:
#     Show_Id Category                       Title Director  \
# 957    s958    Movie  Black Mirror: Bandersnatch      NaN
#
#                                                   Cast        Country  \
# 957  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#           Release_Date Rating Duration  \
# 957  December 28, 2018  TV-MA  312 min
#
#                                                Type  \
# 957  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                            Description     Date_N    Year  \
# 957  In 1984, a young programmer begins to question... 2018-12-28  2018.0
#
#      Minutes Unit
# 957      312  min

# %%
df[df['Category'] == 'TV Show']['Minutes'].max()
# Out:
# 16

# %%
df [(df ['Minutes' ] == 16)&(df ['Category' ] == 'TV Show')]
# Out:
#      Show_Id Category           Title Director  \
# 2538   s2539  TV Show  Grey's Anatomy      NaN
#
#                                                    Cast        Country  \
# 2538  Ellen Pompeo, Sandra Oh, Katherine Heigl, Just...  United States
#
#      Release_Date Rating    Duration                          Type  \
# 2538  May 9, 2020  TV-14  16 Seasons  Romantic TV Shows, TV Dramas
#
#                                             Description     Date_N    Year  \
# 2538  Intern (and eventual resident) Meredith Grey f... 2020-05-09  2020.0
#
#       Minutes     Unit
# 2538       16  Seasons

# %% [markdown]
# 🔴 - Círculo vermelho: :red_circle:
# 🟢 - Círculo verde: :green_circle:
# 🔵 - Círculo azul: :blue_circle:
# ✅ **Isso está correto!**
# ⚠️ **Atenção: Verifique as informações cuidadosamente!**
#
#
# 🧡💻 Analista Power Platform Pleno
# ✔️Atuação Hibrida 3x na semana em São Paulo - São Bernardo do Campo
#
# ➡️Requisitos

# %% [markdown]
# # Qual pais que passui o maior umero de Shows e moveis

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
#
#    Minutes     Unit
# 0        4  Seasons

# %%
df_tvshow=df [df ['Category' ] == 'TV Show' ]

# %%
df_tvshow.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
#
#    Minutes     Unit
# 0        4  Seasons

# %%
df_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
df_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
df.loc[[0,1]]
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#    Minutes     Unit
# 0        4  Seasons
# 1       93      min

# %% [markdown]
# # Ordenar de forma crescente do menor para o maior a Coluna Year

# %%
df.sort_values(by='Year' ).head(20)
# Out:
#      Show_Id Category                                       Title  \
# 7115   s7114    Movie                        To and From New York
# 1765   s1766  TV Show                             Dinner for Five
# 3248   s3249    Movie                     Just Another Love Story
# 5766   s5766    Movie                                    Splatter
# 3840   s3841    Movie                 Mad Ron's Prevues from Hell
# 232     s233    Movie                  A Stoning in Fulham County
# 2962   s2963    Movie                 In Defense of a Married Man
# 7416   s7415    Movie                            Victim of Beauty
# 7151   s7150    Movie                          Too Young the Hero
# 3221   s3222    Movie                      Joseph: King of Dreams
# 2622   s2623    Movie                                Hard Lessons
# 5042   s5042    Movie  Quiet Victory: The Charlie Wedemeyer Story
# 7364   s7363    Movie                            Unspeakable Acts
# ...

# %% [markdown]
# # Ordena de forma decrescente do maior para o menor a Coluna Year

# %%
df.sort_values(by='Year', ascending=False).head(20)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 560     s561    Movie                                           Apaharan
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 1002   s1003    Movie                                        Blue Streak
# 3558   s3559    Movie                                              Leap!
# 1004   s1005    Movie                                       BluffMaster!
# ...

# %% [markdown]
# # Filtar onde a categoria é Filme e o tipo é Drama ou a categoria é Show's de TV e o tipo é TV de criancas.

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
#
#    Minutes     Unit
# 0        4  Seasons

# %%
df.Type.value_counts()
# Out:
# Type
# Documentaries                                                                      334
# Stand-Up Comedy                                                                    321
# Dramas, International Movies                                                       320
# Comedies, Dramas, International Movies                                             243
# Dramas, Independent Movies, International Movies                                   215
#                                                                                   ...
# Crime TV Shows, Romantic TV Shows, Spanish-Language TV Shows                         1
# Crime TV Shows, International TV Shows, Reality TV                                   1
# International Movies, Romantic Movies, Sci-Fi & Fantasy                              1
# Stand-Up Comedy & Talk Shows, TV Mysteries, TV Sci-Fi & Fantasy                      1
# International TV Shows, Spanish-Language TV Shows, Stand-Up Comedy & Talk Shows      1
# ...

# %%
df[(df['Category'] == 'Movie') & (df['Type'] == 'Dramas') ]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df[(df['Category'] == 'TV Show') & (df['Type'] == "Kids' TV") ]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
df[(df['Category'] == 'Movie') & (df['Type'] == 'Dramas') | (df['Category'] == 'TV Show') & (df['Type'] == "Kids' TV") ]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %%
df[((df['Category'] == 'Movie') & (df['Type'] == 'Dramas')) | ((df['Category'] == 'TV Show') & (df['Type'] == "Kids' TV"))]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %%
df.iloc[0:4,8]
# Out:
# 0    4 Seasons
# 1       93 min
# 2       78 min
# 3       80 min
# Name: Duration, dtype: object
